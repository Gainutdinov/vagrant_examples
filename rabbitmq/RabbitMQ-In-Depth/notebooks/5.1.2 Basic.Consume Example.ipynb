# %%
import rabbitpy

# %%
for message in rabbitpy.consume('amqp://guest:guest@rabbit_Primary_InDepth:5672/%2f',
                                'test-messages'):
    message.pprint()            
    message.ack()
# Out:
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fa120b39fdd6> in <module>
#       1 for message in rabbitpy.consume('amqp://guest:guest@rabbit_Primary_InDepth:5672/%2f',
# ----> 2                                 'test-messages'):
# ...
