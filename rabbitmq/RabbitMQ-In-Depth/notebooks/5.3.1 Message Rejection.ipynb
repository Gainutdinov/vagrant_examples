# %%
import rabbitpy

# %%
for message in rabbitpy.consume('amqp://guest:guest@rabbit_Primary_InDepth:5672/%2f',
                                'test-messages'):
    message.pprint()
    print('Redelivered: %s' % message.redelivered)              
    message.reject(True)
# Out:
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: False
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# Redelivered: True
# Exchange:
#
# Routing Key: test-messages
#
# bytearray(b'go')
# ...
